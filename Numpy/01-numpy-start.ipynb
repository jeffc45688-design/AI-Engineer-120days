# %%
import numpy as np
#根據列表建立ndarray物件
ndarr=np.array([3,4,-5])
print(ndarr)
print(ndarr.size)#數量
# Out:
# [ 3  4 -5]
# 3

# %% [markdown]
# list（普通 Python）
# 可以放不同型態
# 速度較慢
# 記憶體不連續（散亂）
#
# ndarray（NumPy）
# 元素必須是 相同型態（同質）
# 速度快（底層是 C 優化）
# 記憶體連續（高效運算）
# 能做向量運算（broadcasting）

# %% [markdown]
# 屬性	意思	結果
# a.size	元素總數	6
# a.shape	各維度大小	(2, 3)
# a.ndim	維度數	2
