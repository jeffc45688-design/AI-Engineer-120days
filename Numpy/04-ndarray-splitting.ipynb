# %%
import numpy as np 
arr=np.array([ 
    [2,4,6,8,10,12], 
    [1,3,5,7,9,11] 
])
result=np.vsplit(arr,2) 
print(result) 
print("-------------------")
result2=np.hsplit(arr,3)
print(result2)
# Out:
# [array([[ 2,  4,  6,  8, 10, 12]]), array([[ 1,  3,  5,  7,  9, 11]])]
# -------------------
# [array([[2, 4],
#        [1, 3]]), array([[6, 8],
#        [5, 7]]), array([[10, 12],
#        [ 9, 11]])]
