# %%
from transformers  import AutoModelForCausalLM,AutoTokenizer
import torch
model_name="sshleifer/tiny-gpt2"
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModelForCausalLM.from_pretrained(model_name)
if tokenizer.pad_token is None:
    tokenizer.pad_token=tokenizer.eos_token
def generated_text(prompt,max_new_tokens=20):
    inputs=tokenizer(prompt,return_tensors="pt")
    with torch.no_grad():
        generated_ids=model.generate(
            **inputs,
            max_new_tokens=max_new_tokens,
            pad_token_id=tokenizer.eos_token_id
        )
    generated_text=tokenizer.decode(generated_ids[0],skip_special_token=True)
    return generated_text
prompt1="AI will change"
prompt2="Qusetion:What is AI?\nAnswer"
prompt3="You are a helpful Ai tutor.\nExplain AI in simple Chinses.\nAnswer"
print("Prompt1",generated_text(prompt1))
print("Prompt2",generated_text(prompt2))
print("Prompt3",generated_text(prompt3))
# Out:
# Loading weights: 100%|██████████| 29/29 [00:00<00:00, 7205.00it/s]
# GPT2LMHeadModel LOAD REPORT from: sshleifer/tiny-gpt2
# Key                                   | Status     |  |
# --------------------------------------+------------+--+-
# transformer.h.{0, 1}.attn.masked_bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Prompt1 AI will change factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors factors
# Prompt2 Qusetion:What is AI?
# Answer stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs stairs
# Prompt3 You are a helpful Ai tutor.
# Explain AI in simple Chinses.
# ...
