# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset,DataLoader
X=torch.tensor([
    [1,2],
    [2,1],
    [3,4],
    [4,3]
],dtype=torch.float32)
Y=torch.tensor([
    [0.0],
    [0.0],
    [1.0],
    [1.0]
])
dataset=TensorDataset(X,Y)
dataloader=DataLoader(
    dataset,
    batch_size=2,
    shuffle=True
)
class Net(nn.Module):
    def __init__(self):
        super().__init__()
        self.fc1=nn.Linear(2,4)
        self.fc2=nn.Linear(4,1)
    def forward(self,x):
        x=self.fc1(x)
        x=torch.relu(x)
        x=self.fc2(x)
        return x
model=Net()
criterion=nn.BCEWithLogitsLoss()
optimizer=optim.Adam(model.parameters(),lr=0.01)
epochs=200
for epoch in range(epochs):
    for X_batch,Y_batch in dataloader:
        y_pred=model(X_batch)
        loss=criterion(y_pred,Y_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    if epoch % 20 == 0:
        print(epoch,loss.item())
with torch.no_grad():
    pred=torch.sigmoid(model(X))
    label=(pred>0.5).int()
print("prediction",label.squeeze())
print("true",Y.squeeze())
# Out:
# 0 0.5190427303314209
# 20 0.37551483511924744
# 40 0.2676663100719452
# 60 0.29324811697006226
# 80 0.23034489154815674
# 100 0.07426207512617111
# 120 0.04877977445721626
# 140 0.03253988176584244
# 160 0.02342216670513153
# 180 0.06951825320720673
# prediction tensor([0, 0, 1, 1], dtype=torch.int32)
# true tensor([0., 0., 1., 1.])
