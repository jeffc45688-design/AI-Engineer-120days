# %%
from transformers import AutoTokenizer,AutoModelForCausalLM
import torch
model_name="sshleifer/tiny-gpt2"
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModelForCausalLM.from_pretrained(model_name)
text="Al will change"
inputs=tokenizer(text,return_tensors="pt")
print("input_ids",inputs["input_ids"])
print("attention_mask",inputs["attention_mask"])
print("tokens",tokenizer.convert_ids_to_tokens(inputs["input_ids"][0]))
with torch.no_grad():
    outputs=model(**inputs)
logits=outputs.logits
print("logits shape",logits.shape)
generated_ids=model.generate(
    **inputs,
    max_new_tokens=10
)
print("generated_ids",generated_ids)
print("generates_text",tokenizer.decode(generated_ids[0],skip_special_tokens=True))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from transforms import AutoTokenizer,AutoModelForCausalLM
#       2 import torch
#       3 model_name="sshleifer/tiny-gpt2"
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transforms\__init__.py:1
# ----> 1 from .safe_html import safe_html, bodyfinder
#       3 # modules = [
#       4 #     'st',             # zopish
#       5 #     'rest',           # docutils
#    (...)
#      29 #     'html_to_web_intelligent_plain_text',
#      30 #     ]
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transforms\safe_html.py:1
# ----> 1 from sgmllib import SGMLParser, SGMLParseError
#       2 import re
#       3 from html import escape
#
# ModuleNotFoundError: No module named 'sgmllib'
