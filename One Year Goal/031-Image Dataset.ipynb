# %%
from torchvision.datasets import ImageFolder
from torchvision import transforms
from torch.utils.data import DataLoader
trans_form=transforms.Compose([
    transforms.Resize((224,224)),
    transforms.ToTensor()
])
dataset=ImageFolder(
    root="dataset",
    transform=trans_form
)
loader=DataLoader(
    dataset,
    batch_size=2,#6張圖一次只丟2張
    shuffle=True
)
print("classes",dataset.classes)
print("class_to_idx",dataset.class_to_idx)
print("dataset size",len(dataset))
for images,labels in loader:
    print("images shape",images.shape) #(batch,channel,h,w)
    print("labels",labels)
# Out:
# classes ['cat', 'dog']
# class_to_idx {'cat': 0, 'dog': 1}
# dataset size 6
# images shape torch.Size([2, 3, 224, 224])
# labels tensor([0, 0])
# images shape torch.Size([2, 3, 224, 224])
# labels tensor([1, 1])
# images shape torch.Size([2, 3, 224, 224])
# labels tensor([1, 0])
