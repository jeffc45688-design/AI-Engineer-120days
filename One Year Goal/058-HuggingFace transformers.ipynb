# %%
from transformers import AutoTokenizer,AutoModel
import torch
model_name="distilbert-base-uncased"
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModel.from_pretrained(model_name)
text="I love AI"
inputs=tokenizer(text,return_tensors="pt")
print("input_ids",inputs["input_ids"])
print("attention_mask",inputs["attention_mask"])
print("tokens",tokenizer.convert_ids_to_tokens(inputs["input_ids"][0]))
with torch.no_grad():
    outputs=model(**inputs)
last_hidden_state=outputs.last_hidden_state
print("last_hidden_state",last_hidden_state.shape)
print(last_hidden_state)
# Out:
# Loading weights: 100%|██████████| 100/100 [00:00<00:00, 6003.27it/s]
# DistilBertModel LOAD REPORT from: distilbert-base-uncased
# Key                     | Status     |  |
# ------------------------+------------+--+-
# vocab_transform.bias    | UNEXPECTED |  |
# vocab_transform.weight  | UNEXPECTED |  |
# vocab_layer_norm.weight | UNEXPECTED |  |
# vocab_layer_norm.bias   | UNEXPECTED |  |
# vocab_projector.bias    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# input_ids [101, 1045, 2293, 9932, 102]
# attention_mask [1, 1, 1, 1, 1]
# tokens [CLS]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 print("tokens",tokenizer.convert_ids_to_tokens(inputs["input_ids"][0]))
#      11 with torch.no_grad():
# ---> 12     outputs=model(**inputs)
#      13 last_hidden_state=outputs.last_hidden_state
#      14 print("last_hidden_state",last_hidden_state.shape)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transformers\utils\generic.py:952, in merge_with_config_defaults.<locals>.wrapper(self, *args, **kwargs)
#     950             output = func(self, *args, **kwargs)
#     951     else:
# --> 952         output = func(self, *args, **kwargs)
#     953 # Restore original config value
#     954 finally:
#     955     if is_causal is not None:
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transformers\utils\output_capturing.py:248, in capture_outputs.<locals>.wrapped_fn.<locals>.wrapper(self, *args, **kwargs)
#     246 # Run the forward
#     247 try:
# --> 248     outputs = func(self, *args, **kwargs)
#     249 # Reset the states
#     250 finally:
#     251     _active_collector.reset(output_token)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:413, in DistilBertModel.forward(self, input_ids, attention_mask, inputs_embeds, position_ids, **kwargs)
#     410 if (input_ids is None) ^ (inputs_embeds is not None):
#     411     raise ValueError("You must specify exactly one of input_ids or inputs_embeds")
# --> 413 embeddings = self.embeddings(input_ids, inputs_embeds, position_ids)
#     415 attention_mask = create_bidirectional_mask(
#     416     config=self.config,
#     417     inputs_embeds=embeddings,
#     418     attention_mask=attention_mask,
#     419 )
#     421 return self.transformer(
#     422     hidden_states=embeddings,
#     423     attention_mask=attention_mask,
#     424     **kwargs,
#     425 )
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transformers\utils\deprecation.py:171, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     167 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     168     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     169     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 171 return func(*args, **kwargs)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\transformers\models\distilbert\modeling_distilbert.py:103, in Embeddings.forward(self, input_ids, inputs_embeds, position_ids)
#      95 @deprecate_kwarg("input_embeds", version="5.6.0", new_name="inputs_embeds")
#      96 def forward(
#      97     self,
#    (...)
#     100     position_ids: torch.LongTensor | None = None,
#     101 ) -> torch.Tensor:
#     102     if input_ids is not None:
# --> 103         inputs_embeds = self.word_embeddings(input_ids)  # (bs, max_seq_length, dim)
#     105     seq_length = inputs_embeds.size(1)
#     107     if position_ids is None:
#     108         # Setting the position-ids to the registered buffer in constructor, it helps
#     109         # when tracing the model without passing position-ids, solves
#     110         # issues similar to issue #5664
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\modules\sparse.py:191, in Embedding.forward(self, input)
#     190 def forward(self, input: Tensor) -> Tensor:
# --> 191     return F.embedding(
#     192         input,
#     193         self.weight,
#     194         self.padding_idx,
#     195         self.max_norm,
#     196         self.norm_type,
#     197         self.scale_grad_by_freq,
#     198         self.sparse,
#     199     )
#
# File c:\Users\marce\ai-career-2026\ai_env\lib\site-packages\torch\nn\functional.py:2567, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2561     # Note [embedding_renorm set_grad_enabled]
#    2562     # XXX: equivalent to
#    2563     # with torch.no_grad():
#    2564     #   torch.embedding_renorm_
#    2565     # remove once script supports set_grad_enabled
#    2566     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2567 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# TypeError: embedding(): argument 'indices' (position 2) must be Tensor, not list
