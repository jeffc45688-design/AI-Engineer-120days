# %%
text="I Love AI!!! and AI is GREAT."
text=text.lower()
print(text)
for ch in ["!",".",":",";"]:
    text=text.replace(ch,"")
print(text)
tokens=text.split()
print(tokens)
# Out:
# i love ai!!! and ai is great.
# i love ai and ai is great
# ['i', 'love', 'ai', 'and', 'ai', 'is', 'great']
