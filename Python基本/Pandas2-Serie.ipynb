# %%
import pandas as pd
data=pd.Series([5,4,-2,3,7],index=["a","b","c","d","e"])
print(data)
print("資料型態",data.dtype)
print("資料數量",data.size)
print("資料索引",data.index)
print(data.iloc[2],data.iloc[0])#integer location
print(data["e"],data["d"])
# Out:
# a    5
# b    4
# c   -2
# d    3
# e    7
# dtype: int64
# 資料型態 int64
# 資料數量 5
# 資料索引 Index(['a', 'b', 'c', 'd', 'e'], dtype='str')
# -2 5
# 7 3

# %%
# 數字的運算
import pandas as pd
data=pd.Series([5,4,-2,3,7],index=["a","b","c","d","e"])
print("最大值",data.max())
print("總和",data.sum())
print("標準差",data.std())
print("中位數",data.median())
print("最大的三個數",data.nlargest(3))#data.nsmallest()
# Out:
# 最大值 7
# 總和 17
# 標準差 3.361547262794322
# 中位數 4.0
# 最大的三個數 e    7
# a    5
# b    4
# dtype: int64

# %%
#字串運算:基本,串接,搜尋,取代
import pandas as pd
data=pd.Series(["您好","Python","Pandas"])
# print(data.str.lower())#變小寫,中文不變
# print(data.str.len()) #每個字長度
# print(data.str.cat(sep="-"))#把字串串起
# print(data.str.contains("P"))#是否包含 轉布林值
print(data.str.replace("您好","Hello"))#,
# Out:
# 0     Hello
# 1    Python
# 2    Pandas
# dtype: str
