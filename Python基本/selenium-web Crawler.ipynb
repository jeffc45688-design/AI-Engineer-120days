# %%
# 載入Selenium相關模組
# 大寫 Chrome → 類別（用來產生 driver）
# 小寫 chrome（資料夾名） → 模組（module）
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
options=Options()
service=Service(r"C:\Users\marce\ai-career-2026\Python基本\chromedriver.exe")
driver=webdriver.Chrome()# 讓 Selenium 自己處理 driver
driver.get("https://www.ptt.cc/bbs/Stock/index.html")
# print(driver.page_source)#取的網頁原始碼
tags=driver.find_elements(By.CLASS_NAME,"title")
for tag in tags:
    print(tag.text)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
options=Options()
service=Service(r"C:\Users\marce\ai-career-2026\Python基本\chromedriver.exe")
driver=webdriver.Chrome()# 讓 Selenium 自己處理 driver
driver.get("https://www.ptt.cc/bbs/Stock/index.html")
# print(driver.page_source)#取的網頁原始碼
tags=driver.find_elements(By.CLASS_NAME,"title")
for tag in tags:
    print(tag.text)
link=driver.find_element(By.LINK_TEXT,"‹ 上頁")
link.click()		
tags=driver.find_elements(By.CLASS_NAME,"title")
for tag in tags:
    print(tag.text)
driver.quit()
# Out:
# [新聞] 南亞科股價25→326元 謝金河曝「這群大咖
# [標的] AMZN.US 買夠多
# [新聞] 台美關稅協定春節前簽署 談判團隊近日再
# (已被大鳥守衛刪除) <androider> 4-2-1
# Re: [請益] LLM到底有沒有護城河 大家都會不是白菜價
# Re: [標的] AMZN.US 買夠多
# Re: [請益] LLM到底有沒有護城河 大家都會不是白菜價
# Fw: [請益] 2022年為何是股債雙殺的一年
# [閒聊] 2026/02/09 盤中閒聊
# [情報] 3017奇鋐 115年1月營收
# [新聞] 台股暴力反彈！大漲883點至32666　台積電大漲55元至1835
# Re: [請益] 綠角說正二不能長期投資！？
# Re: [標的] 2527宏璟 逆風多
# [新聞] 韓媒：韓股市值已超越台灣與德國 全球第
# [公告] 股票板板規 v4.7 (2024/10/06 修正)
# [公告] 4-6-1罰則將在1/22開始到年底加重至30天
# [閒聊] 2026/02/09 盤中閒聊
# [新聞] 從軍工跨足金融！網紅無人機Anduril創辦
# Re: [新聞] 阿曼會談剛落幕 美制裁伊朗石油出口、14艘
# [新聞] 封關前大翻車？台股違約交割爆1737萬元
# [標的] 2441 超豐 過年抱股安心多
# [請益] 綠角說正二不能長期投資！？
# [請益] LLM到底有沒有護城河 大家都會不是白菜價
# Re: [請益] 綠角說正二不能長期投資！？
# [新聞] 從GPU到CPU全面告急：美系晶片封鎖在即？
# Re: [請益] 綠角說正二不能長期投資！？
# Re: [新聞] 扯！南韓Bithumb誤向用戶發送62萬枚比特
# [新聞] 兩路搶無人船大單 台船今年穩賺
# [新聞] 日媒：中國加強管制後　已批准多項對日本
# [新聞] 歐盟認定TikTok「上癮式設計」違法！TikT
# [請益] 高市早苗大勝,明天開盤要賭什麼？
# [新聞] 信達生物宣布與禮來公司達成策略合作，在
# [新聞] 台灣遭點名俄石腦油最大買家！《路透》
# [新聞] 明日股價續揚？台船釋海鯤號潛航測試影
# [新聞] 日本眾議院改選 自民黨單獨過半
# Re: [請益] 高市早苗大勝,明天開盤要賭什麼？
# ...
